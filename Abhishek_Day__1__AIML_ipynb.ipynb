# %% [markdown]
# phython3

# %%
#Build a calculator
#concept : Type casting ,variable,Data Type
a = int(input("Enter first number"))
b = int(input("Enter second number"))
print("Addition is:", a+b)
print(f"Addition is : {a+b}") #F-string (very crucial)
print(f"substraction is: {a-b}")
print(f"multiplication is: {a*b}")
print(f"division is: {a/b}")
# Out:
# Enter first number15
# Enter second number13
# Addition is: 28
# Addition is : 28
# substraction is: 2
# multiplication is: 195
# division is: 1.1538461538461537

# %%
name= input("Enter your name")
age= (input("Enter your age"))
dept= input("Enter your department")
print(f"My name is {name},age is {age} & the department is {dept}")
# Out:
# Enter your nameAbhishek
# Enter your age20
# Enter your departmentECE
# My name is Abhishek,age is 20 & the department is ECE

# %% [markdown]
# EXERCISE

# %%
city =input("enter your city name")
print(f"your city {city}")
# Out:
# enter your city namekokata
# your city kokata

# %%
# Create varibles for name,salary,and job role
name=input("enter your name")
salary=float(input("enter your salary"))
job_role=input("enter your job role")
# Out:
# enter your nameAbhishek
# enter your salary150000
# enter your job roleweb Dev

# %%
# input 2 numbers and give the sum
a= int(input("enter first number"))
b= int(input("enter second number"))

# %%
#print welcome message using input
message=input("enter your message")
print(f"welcome {message}")
# Out:
# enter your messagebatak gang
# welcome batak gang

# %%
#popular Data types in python
# list vs Tuple
roles= ("AI Enginner", "Freelancer software Devloper","desingner", "testre",)#list
age=(2000,4000,6000) #tuple
# SET vs Dictionary
name={"alex","yuli"} #set
age={"alex":2000,"yuli":4000} #dictionary

thisdict ={
    "brand": "Ford",#key : value
    "model" :"Mustang"
}

# %%
# if-else-elif statement & identation
# lets check your eligible for driving
age=int(input("enter your age"))
if age>=18:
    print("you are eligible for driving")
    if age <18:
      print("you shouldont drive")
# Out:
# enter your age20
# you are eligible for driving

# %%
# if-else-elif statement & identation
# lets find greatest number among three numbers
# logical operators : and ,or, not
a = int(input("Enter a:"))
b = int(input("Enter b:"))
c = int(input("Enter c:"))
if a>b and a>c:
        print("a is the greatest")
elif b>a and b>c:
            print("b is the greatest")
else:
  print("c is the greatest")
# Out:
# Enter a:11
# Enter b:17
# Enter c:7
# b is the greatest

# %%
#modules
import math
a=25
print(math.sqrt(a))
# Out:
# 5.0

# %%
# How can you print current date and time
import datetime
a=datetime.datetime.now()
print(a)
# Out:
# 2026-03-16 07:20:51.424281

# %%
#in future when we make projects we should use modules like this :
import numpy
import pandas
import matplotlib
import tensorflow
import pygame
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
